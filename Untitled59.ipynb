# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarsinh0/BASICS-OF-PANDA/blob/main/Untitled59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the module
import pandas as pd
import numpy as np


# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
							'Mahindra', 'Maruti', 'Hyundai',
							'Renault', 'Tata', 'Maruti'],
					'Year': [2012, 2014, 2011, 2015, 2012,
							2016, 2014, 2018, 2019],
					'Kms Driven': [50000, 30000, 60000,
									25000, None, 46000,
									31000, 15000, 12000],
					'City': ['Gurgaon', 'Delhi', 'Mumbai',
							'Delhi', None, 'Delhi',
							'Mumbai', 'Chennai', 'Ghaziabad'],
					'Mileage': [28, 27, 25, 26, 28,
								29, 24, 21, None]})

data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012     50000.0    Gurgaon     28.0
# 1   Hyundai  2014     30000.0      Delhi     27.0
# 2      Tata  2011     60000.0     Mumbai     25.0
# 3  Mahindra  2015     25000.0      Delhi     26.0
# 4    Maruti  2012         NaN       None     28.0
# 5   Hyundai  2016     46000.0      Delhi     29.0
# 6   Renault  2014     31000.0     Mumbai     24.0
# 7      Tata  2018     15000.0    Chennai     21.0
# 8    Maruti  2019     12000.0  Ghaziabad      NaN

# %%
y=data.sort_values("Brand",axis=0,ascending=True,na_position='last')
y
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 1   Hyundai  2014     30000.0      Delhi     27.0
# 5   Hyundai  2016     46000.0      Delhi     29.0
# 3  Mahindra  2015     25000.0      Delhi     26.0
# 0    Maruti  2012     50000.0    Gurgaon     28.0
# 4    Maruti  2012         NaN       None     28.0
# 8    Maruti  2019     12000.0  Ghaziabad      NaN
# 6   Renault  2014     31000.0     Mumbai     24.0
# 2      Tata  2011     60000.0     Mumbai     25.0
# 7      Tata  2018     15000.0    Chennai     21.0

# %%
data.sort_values(['Brand','Mileage'],axis=0,ascending=True)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 1   Hyundai  2014     30000.0      Delhi     27.0
# 5   Hyundai  2016     46000.0      Delhi     29.0
# 3  Mahindra  2015     25000.0      Delhi     26.0
# 0    Maruti  2012     50000.0    Gurgaon     28.0
# 4    Maruti  2012         NaN       None     28.0
# 8    Maruti  2019     12000.0  Ghaziabad      NaN
# 6   Renault  2014     31000.0     Mumbai     24.0
# 7      Tata  2018     15000.0    Chennai     21.0
# 2      Tata  2011     60000.0     Mumbai     25.0

# %%
print(data.groupby('Brand').groups)
# Out:
# {'Hyundai': [1, 5], 'Mahindra': [3], 'Maruti': [0, 4, 8], 'Renault': [6], 'Tata': [2, 7]}

# %%
df=data.groupby('Brand')
df.first()    # take first item from every group
# Out:
#           Year  Kms Driven     City  Mileage
# Brand
# Hyundai   2014     30000.0    Delhi     27.0
# Mahindra  2015     25000.0    Delhi     26.0
# Maruti    2012     50000.0  Gurgaon     28.0
# Renault   2014     31000.0   Mumbai     24.0
# Tata      2011     60000.0   Mumbai     25.0

# %%
print(data.groupby(['Brand','Year']).groups)
# Out:
# {('Hyundai', 2014): [1], ('Hyundai', 2016): [5], ('Mahindra', 2015): [3], ('Maruti', 2012): [0, 4], ('Maruti', 2019): [8], ('Renault', 2014): [6], ('Tata', 2011): [2], ('Tata', 2018): [7]}

# %%
x=data.groupby('Brand')
x.aggregate(np.sum)
# Out:
# <ipython-input-33-6ce37e6a88ae>:2: FutureWarning: The operation <function sum at 0x7a599d780310> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   x.aggregate(np.sum)
#           Year  Kms Driven  Mileage
# Brand
# Hyundai   4030     76000.0     56.0
# Mahindra  2015     25000.0     26.0
# Maruti    6043     62000.0     56.0
# Renault   2014     31000.0     24.0
# Tata      4029     75000.0     46.0

# %%
y=data.groupby(['Brand','Mileage'])
y.aggregate(np.sum)
# Out:
# <ipython-input-35-38641c47479c>:2: FutureWarning: The operation <function sum at 0x7a599d780310> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   y.aggregate(np.sum)
#                   Year  Kms Driven
# Brand    Mileage
# Hyundai  27.0     2014     30000.0
#          29.0     2016     46000.0
# Mahindra 26.0     2015     25000.0
# Maruti   28.0     4024     50000.0
# Renault  24.0     2014     31000.0
# Tata     21.0     2018     15000.0
#          25.0     2011     60000.0

# %%
z=data.groupby('Brand')
z['Mileage'].agg([np.sum,np.mean,np.std])
# Out:
#            sum  mean       std
# Brand
# Hyundai   56.0  28.0  1.414214
# Mahindra  26.0  26.0       NaN
# Maruti    56.0  28.0  0.000000
# Renault   24.0  24.0       NaN
# Tata      46.0  23.0  2.828427

# %%
z=data.groupby('Brand')
z.agg({'Mileage':'median','Kms Driven':'std'})
# Out:
#           Mileage    Kms Driven
# Brand
# Hyundai      28.0  11313.708499
# Mahindra     26.0           NaN
# Maruti       28.0  26870.057685
# Renault      24.0           NaN
# Tata         23.0  31819.805153

# %%
df=pd.DataFrame({'p':range(5),'s':range(3,8)})
df
# Out:
#    p  s
# 0  0  3
# 1  1  4
# 2  2  5
# 3  3  6
# 4  4  7

# %%
df.transform(lambda x: x+2)
# Out:
#    p  s
# 0  2  5
# 1  3  6
# 2  4  7
# 3  5  8
# 4  6  9

# %%
df1=pd.Series(range(4))
df1
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
df1.transform([np.sqrt,np.exp])
# Out:
# <ipython-input-72-583cfd722984>:1: FutureWarning: ['name'] did not transform successfully. If any error is raised, this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df1.transform([np.sqrt,np.exp])
#         age
#        sqrt           exp
# 0  5.477226  1.068647e+13
# 1  5.656854  7.896296e+13

# %%
d1={'name':['a','b'],'age':[30,32]}
d2={'name':['b','d'],'age':[32,80]}
df1=pd.DataFrame(d1)
df1
# Out:
#   name  age
# 0    a   30
# 1    b   32

# %%
df2=pd.DataFrame(d2)
df2
# Out:
#   name  age
# 0    c   32
# 1    d   80

# %%
x=df1,df2
con=pd.concat(x)
con
# Out:
#   name  age
# 0    a   30
# 1    b   32
# 0    c   32
# 1    d   80

# %%
con1=pd.concat([df1,df2],axis=0,join='inner')
con1
# Out:
#   name  age
# 0    a   30
# 1    b   32
# 0    c   32
# 1    d   80

# %%
con2=pd.concat([df1,df2],axis=1,join='outer')
con2
# Out:
#   name  age name  age
# 0    a   30    c   32
# 1    b   32    d   80

# %%
x=df1.append(df2)
x
# Out:
# <ipython-input-78-10f3ad09c16d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x=df1.append(df2)
#   name  age
# 0    a   30
# 1    b   32
# 0    c   32
# 1    d   80

# %%
x=pd.merge(df1,df2,on='age')
x
# Out:
#   name_x  age name_y
# 0      b   32      c

# %%
y=pd.merge(df1,df2,on=['age','name'])
y
# Out:
# Empty DataFrame
# Columns: [name, age]
# Index: []
